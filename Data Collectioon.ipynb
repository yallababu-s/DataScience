# %%
#Data Collection
#Data Can be form of Text,Tables and Images, Videos

# %%
#Types of Data Collected to feed a predictive model are 
#1.Categorical Data (String) 2.Numeric Data (number)3.Times Series Data (Date) 4.Text Data (articles/post)

# %% [markdown]
# # Loading DataSet
# #Data Collection

# %%
#import Libraries
import pandas as pd
import numpy as np
import seaborn as sns
dataset = pd.read_csv("50_Startups.csv")

# %%
dataset
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
dataset1 = pd.read_csv("CKD.csv")
dataset1
# Out:
#            age         bp sg   al   su     rbc        pc         pcc  \
# 0     2.000000  76.459948  c  3.0  0.0  normal  abnormal  notpresent
# 1     3.000000  76.459948  c  2.0  0.0  normal    normal  notpresent
# 2     4.000000  76.459948  a  1.0  0.0  normal    normal  notpresent
# 3     5.000000  76.459948  d  1.0  0.0  normal    normal  notpresent
# 4     5.000000  50.000000  c  0.0  0.0  normal    normal  notpresent
# ..         ...        ... ..  ...  ...     ...       ...         ...
# 394  51.492308  70.000000  a  0.0  0.0  normal    normal  notpresent
# 395  51.492308  70.000000  c  0.0  2.0  normal    normal  notpresent
# 396  51.492308  70.000000  c  3.0  0.0  normal    normal  notpresent
# 397  51.492308  90.000000  a  0.0  0.0  normal    normal  notpresent
# 398  51.492308  80.000000  a  0.0  0.0  normal    normal  notpresent
#
#              ba         bgr  ...        pcv            wc        rc  htn   dm  \
# ...

# %%
dataset2 = pd.read_csv("insurance_pre.csv")
dataset2
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset3 = pd.read_csv("Placement_Data_Full_Class.csv")
dataset3
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset4 = pd.read_csv("Salary_Data.csv")
dataset4
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
dataset5 = pd.read_csv("Social_Network_Ads.csv")
dataset5
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
#pip install kagglehub
# Out:
# ...
#   Obtaining dependency information for kagglehub from https://files.pythonhosted.org/packages/38/d0/6085847723db5bbfb3184f1c77de76cf33c3c3eec9d5dd0229187d2a0ab8/kagglehub-0.3.5-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/44.8 kB ? eta -:--:--
#    ---------------------------------------- 44.8/44.8 kB 2.3 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Data Collection using zip file

# %%
import zipfile
import os
# Path to the ZIP file
zip_file_path = 'FakeJobs.zip'
# Folder to extract files to
extracted_folder_path = 'extracted_data'

# %%
# Extract ZIP file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extracted_folder_path)

# %%
# List the extracted files
extracted_files = os.listdir(extracted_folder_path)
print(extracted_files)
# Out:
# ['Fake Postings.csv']

# %%
# Identify the CSV file (assuming there is only one CSV file)
csv_file = [file for file in extracted_files if file.endswith(".csv")]
if csv_file:
    csv_file_path = os.path.join(extracted_folder_path, csv_file[0])
    print("CSV file found:", csv_file_path)
else:
    print("No CSV file found!")
    exit()

# Load the dataset into a pandas DataFrame
datazip = pd.read_csv(csv_file_path)
datazip
# Out:
# CSV file found: extracted_data\Fake Postings.csv
#                                              title  \
# 0                              Mental health nurse
# 1                        Conference centre manager
# 2                                   Engineer, land
# 3                          Forest/woodland manager
# 4     Production designer, theatre/television/film
# ...                                            ...
# 9995                           Designer, furniture
# 9996                Therapist, speech and language
# 9997                             Therapist, sports
# 9998                   Clinical research associate
# 9999                           Hospital pharmacist
#
#                                             description  \
# 0     Arm drive court sure vote. Earn $5000/week! Im...
# 1     Government whom its bed go tax tree black. Ear...
# 2     I member discuss follow way there nation. Earn...
# 3     House across wait approach face. Earn $5000/we...
# ...
