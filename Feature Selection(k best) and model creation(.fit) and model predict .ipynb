# %%
#Select K =n n here ex:3 (call1,2,3 best 3 input (imp features) model score stores to all the models to chisquare)
#Selectk_classificatio.py   saved all the class and def function names

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
#import all the libraries and def functions
import pandas as pd
from sklearn.model_selection import train_test_split 
import time
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor #KNN
import pickle
import matplotlib.pyplot as plt

# %%
def selectkbest(indep_X,dep_Y,n):
        test = SelectKBest(score_func=f_regression, k=n)
        fit1= test.fit(indep_X,dep_Y)
        # summarize scores       
        selectk_features = fit1.transform(indep_X)
        return selectk_features

# %%
#.fit is model creation

# %%
def split_scalar(indep_X,dep_Y):
        X_train, X_test, y_train, y_test = train_test_split(indep_X, dep_Y, test_size = 0.25, random_state = 0)
        sc = StandardScaler()
        X_train = sc.fit_transform(X_train)
        X_test = sc.transform(X_test)    
        return X_train, X_test, y_train, y_test
 #r2 score   
def r2_prediction(regressor,X_test,y_test):
    y_pred = regressor.predict(X_test)
    from sklearn.metrics import r2_score
    r2=r2_score(y_test,y_pred)
    return r2

def MLinear(X_train,y_train,X_test):       
        # Fitting K-NN to the Training set
        from sklearn.linear_model import LinearRegression
        regressor = LinearRegression()
        regressor.fit(X_train, y_train)
        r2=r2_prediction(regressor,X_test,y_test)
        return  r2     
    
def svm_linear(X_train,y_train,X_test):
                
        from sklearn.svm import SVR
        regressor = SVR(kernel = 'linear')
        regressor.fit(X_train, y_train)
        r2=r2_prediction(regressor,X_test,y_test)
        return  r2  
    
#non linear-Nl    
def svm_NL(X_train,y_train,X_test):
                
        from sklearn.svm import SVR
        regressor = SVR(kernel = 'rbf')
        regressor.fit(X_train, y_train)
        r2=r2_prediction(regressor,X_test,y_test)
        return  r2 
    
def KNeighborsRegressor(X_train,y_train,X_test):
        
        # Fitting K-NN to the Training setC
        from sklearn.neighbors import KNeighborsRegressor
        regressor = KNeighborsRegressor(n_neighbors=5)
        regressor.fit(X_train, y_train)
        r2=r2_prediction(regressor,X_test,y_test)
        return  r2 
      
def Decision(X_train,y_train,X_test):
        
        # Fitting K-NN to the Training setC
        from sklearn.tree import DecisionTreeRegressor
        regressor = DecisionTreeRegressor(random_state = 0)
        regressor.fit(X_train, y_train)
        r2=r2_prediction(regressor,X_test,y_test)
        return  r2     


def Random(X_train,y_train,X_test):       
        # Fitting K-NN to the Training set
        from sklearn.ensemble import RandomForestRegressor
        regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
        regressor.fit(X_train, y_train)
        r2=r2_prediction(regressor,X_test,y_test)
        return  r2 
    
def selectk_regression(acclin,accsvml,accsvmnl,accKnr,accdes,accrf): 
    
    dataframe=pd.DataFrame(index=['f_regression'],columns=['MultiLinear','SVMl','SVMnl','Knr','Decision','Random'])
    for number,idex in enumerate(dataframe.index):      
        dataframe['MultiLinear'][idex]=acclin[number]       
        dataframe['SVMl'][idex]=accsvml[number]
        dataframe['SVMnl'][idex]=accsvmnl[number]
        dataframe['Knr'][idex]=accKnr[number]
        #dataframe['Navie'][idex]=accnav[number]--only classification has Navie bayes
        dataframe['Decision'][idex]=accdes[number]
        dataframe['Random'][idex]=accrf[number]
    return dataframe

# %%
#dataset1=pd.read_csv("superstore_reg.csv",index_col=None)
dataset1=pd.read_csv("50_Startups.csv",index_col=None)
dataset1.columns
# Out:
# Index(['R&D Spend', 'Administration', 'Marketing Spend', 'State', 'Profit'], dtype='object')

# %%
#dataset1=dataset1.drop('Row ID', axis=1)

# %%
# Check for missing values
#print(dataset1.isnull())  # Returns a DataFrame of booleans
#print(dataset1.isnull().sum())  # Sum missing values per column
#print(dataset1.isnull().sum().sum())  # Total missing values in the entire dataset

# %%
#backup dataset
df2 = dataset1

# %%
df2 = df2.dropna(axis=0)  # Drop rows with any missing values
# Drop rows with any missing values

# %%
df2 = df2.dropna(axis=1)  # Drop columns with missing values

# %%
#convert yes/no to 1 and 0 and drop repetitive column
df2 = pd.get_dummies(df2, drop_first=True)
df2 = df2.astype(float)
#input and output column split
indep_X=df2.drop('Profit', axis=1)
dep_Y=df2['Profit']

# %%
df2.shape
# Out:
# (50, 6)

# %%
dep_Y
# Out:
# 0     192261.83
# 1     191792.06
# 2     191050.39
# 3     182901.99
# 4     166187.94
# 5     156991.12
# 6     156122.51
# 7     155752.60
# 8     152211.77
# 9     149759.96
# 10    146121.95
# 11    144259.40
# 12    141585.52
# 13    134307.35
# 14    132602.65
# 15    129917.04
# 16    126992.93
# 17    125370.37
# 18    124266.90
# 19    122776.86
# 20    118474.03
# 21    111313.02
# 22    110352.25
# 23    108733.99
# 24    108552.04
# 25    107404.34
# 26    105733.54
# 27    105008.31
# 28    103282.38
# 29    101004.64
# 30     99937.59
# 31     97483.56
# 32     97427.84
# 33     96778.92
# 34     96712.80
# 35     96479.51
# 36     90708.19
# 37     89949.14
# 38     81229.06
# 39     81005.76
# 40     78239.91
# 41     77798.83
# 42     71498.49
# 43     69758.98
# 44     65200.33
# 45     64926.08
# 46     49490.75
# 47     42559.73
# 48     35673.41
# 49     14681.40
# Name: Profit, dtype: float64

# %%
# Check for missing values
#print(dataset1.isnull())  # Returns a DataFrame of booleans
print(df2.isnull().sum())  # Sum missing values per column
print(df2.isnull().sum().sum())  # Total missing values in the entire dataset
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# Profit             0
# State_Florida      0
# State_New York     0
# dtype: int64
# 0

# %%
df2.columns
# Out:
# Index(['R&D Spend', 'Administration', 'Marketing Spend', 'Profit',
#        'State_Florida', 'State_New York'],
#       dtype='object')

# %%
kbest = selectkbest(indep_X,dep_Y,5) 
#kbest = SelectKBest(score_func=f_regression,k=6)
#ValueError: Input X contains NaN.
#SelectKBest does not accept missing values encoded as NaN natively. 
#ValueError --drop nan and isnull(any)

# %%
#best 5 input columns , we can modify this
accmlin=[]
accsvml=[]
accsvmnl=[]
accKnr=[]
accnav=[]
accdes=[]
accrf=[]
#to store data(acc) in empty list

# %%
kbest
#6 best input columns
# Out:
# array([[1.6534920e+05, 1.3689780e+05, 4.7178410e+05, 0.0000000e+00,
#         1.0000000e+00],
#        [1.6259770e+05, 1.5137759e+05, 4.4389853e+05, 0.0000000e+00,
#         0.0000000e+00],
#        [1.5344151e+05, 1.0114555e+05, 4.0793454e+05, 1.0000000e+00,
#         0.0000000e+00],
#        [1.4437241e+05, 1.1867185e+05, 3.8319962e+05, 0.0000000e+00,
#         1.0000000e+00],
#        [1.4210734e+05, 9.1391770e+04, 3.6616842e+05, 1.0000000e+00,
#         0.0000000e+00],
#        [1.3187690e+05, 9.9814710e+04, 3.6286136e+05, 0.0000000e+00,
#         1.0000000e+00],
#        [1.3461546e+05, 1.4719887e+05, 1.2771682e+05, 0.0000000e+00,
#         0.0000000e+00],
#        [1.3029813e+05, 1.4553006e+05, 3.2387668e+05, 1.0000000e+00,
#         0.0000000e+00],
#        [1.2054252e+05, 1.4871895e+05, 3.1161329e+05, 0.0000000e+00,
#         1.0000000e+00],
#        [1.2333488e+05, 1.0867917e+05, 3.0498162e+05, 0.0000000e+00,
#         0.0000000e+00],
# ...

# %% [markdown]
# # regression kbest features(imp inputs)

# %%
X_train, X_test, y_train, y_test=split_scalar(kbest,dep_Y) 
#for loop used for only regressionand other, not used in slect K classification
#for i in kbest:  #for loop not mention in def no need here   
r2=MLinear(X_train,y_train,X_test)
accmlin.append(r2)
    
r2=svm_linear(X_train,y_train,X_test)    
accsvml.append(r2)
    
r2=svm_NL(X_train,y_train,X_test)
accsvmnl.append(r2)
    
r2=KNeighborsRegressor(X_train,y_train,X_test)
accKnr.append(r2)
    
r2=Decision(X_train,y_train,X_test)
accdes.append(r2)
    
r2=Random(X_train,y_train,X_test)
accrf.append(r2)

# %%
result=selectk_regression(accmlin,accsvml,accsvmnl,accKnr,accdes,accrf)

# %%
result
#6
# Out:
#              MultiLinear      SVMl     SVMnl     Knr  Decision    Random
# f_regression    0.931582 -0.062264 -0.064173  0.4369  0.939642  0.946748

# %%
#replace r2 with r2_r,r2_d...etc each model to get better score

# %%
#best 5 input columns , we can modify this to get result
kbest=selectkbest(indep_X,dep_Y,50)       

accmlin=[]
accsvml=[]
accsvmnl=[]
accKnr=[]
accdes=[]
accrf=[]

# %%
result
#5o
# Out:
#              MultiLinear      SVMl     SVMnl     Knr  Decision    Random
# f_regression    0.931582 -0.062264 -0.064173  0.4369  0.939642  0.946748

# %%
#best 30 input columns , we can modify this to get result
kbest=selectkbest(indep_X,dep_Y,30)       

accmlin=[]
accsvml=[]
accsvmnl=[]
accKnr=[]
accdes=[]
accrf=[]

# %%
result
#30
# Out:
#              MultiLinear      SVMl     SVMnl     Knr  Decision    Random
# f_regression    0.931582 -0.062264 -0.064173  0.4369  0.939642  0.946748

# %%
#Best Accuracy Model is Random Forest

# %%
# Find the model with the highest R^2 score for f_regression
best_model_name = result.loc['f_regression'].idxmax()
best_r2 = result.loc['f_regression'].max()
best_model_name
# Out:
# 'Random'

# %%
# Retrain the best model on the entire dataset (or use a larger training set if needed)
regressor = RandomForestRegressor(n_estimators=10, random_state=0) # Use the imported class
regressor.fit(kbest, dep_Y)
#xtrain=kbest,ytrain to model creation
# Out:
# RandomForestRegressor(n_estimators=10, random_state=0)

# %%
#save best model
import pickle

# %%
# Save the model to a file
filename = 'best_model_random.sav'
pickle.dump(regressor, open(filename, 'wb'))
#dump to auto save .sav file

# %%
#model=pickle.load(open(filename,"rb"))
# Load the saved model
loaded_model = pickle.load(open(filename, 'rb'))

# %%
# prediction
new_data = kbest
new_data_df = pd.DataFrame(new_data, columns=indep_X.columns)
new_data_kbest = selectkbest(new_data_df, dep_Y, 6)   
new_data_scaled = StandardScaler().fit_transform(new_data_kbest)  #X_train

prediction = loaded_model.predict(new_data_scaled)     #X_train
print("Predicted Profit:", prediction)
# Out:
# Predicted Profit: [42089.282 40541.279 40541.279 42089.282 40541.279 42089.282 40541.279
#  40541.279 42089.282 40541.279 40541.279 40541.279 40541.279 40541.279
#  40541.279 42089.282 40541.279 42089.282 40541.279 42089.282 40541.279
#  42089.282 40541.279 40541.279 42089.282 40541.279 40541.279 42089.282
#  40541.279 42089.282 40541.279 42089.282 40541.279 40541.279 40541.279
#  42089.282 40541.279 40541.279 42089.282 40541.279 40541.279 40541.279
#  40541.279 42089.282 40541.279 42089.282 40541.279 40541.279 42089.282
#  40541.279]

# %%
#indep_X=df2.drop('Profit', axis=1)
#dep_Y=df2['Profit']

#Postal_Code=float(input("Postal Code:"))
#Sales=float(input("Sales:"))
#Discount=float(input("Discount:"))
#Ship Date=int(input("Ship Date"))
#Sales=int(input("Sales"))
#dynamic end user  inputs

#'', '', '', '', '',
#'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#'Product Name', '', 'Quantity', 'Discount', 
#'Profit'---output

# %%
#result=model.predict([[Postal_Code,Sales,Discount]])
#multi 5 inputs to get 1 output(profit)

#AttributeError: 'numpy.ndarray' object has no attribute 'predict'
